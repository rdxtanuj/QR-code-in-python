# %%
import qrcode
import matplotlib.pyplot as plt

# %%
data="https://www.linkedin.com/in/tanuj-kumar-90876127a/"

# %%
filename="MY_QRCODE.png"

# %%
image=qrcode.make(data)

# %%
plt.imshow(image,"gray")
